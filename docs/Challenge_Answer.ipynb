# %% [markdown]
# # Challenge Analysis
#
# ***"Generated answer and performance analysis, delivery and visualization." - by Pentlandite***
#
# The following plot visualizes the relationship between iterations, time, and fitness:
#
# - **Blue Line**: Represents the time taken for each iteration.
# - **Red Line**: Represents the fitness value for each iteration.
#
# The dual y-axis plot effectively illustrates the improvement in fitness over time and the corresponding increase in computational effort.

# %% [markdown]
# ## Challenge 1
#
# **With the base economic conditions and physical properties, what is the optimal circuit for 42 units?**

# %% [markdown]
# **Answer vector**:
#
# [40, 30, 18, 1, 30, 31, 36, 22, 9, 23, 15, 19, 26, 42, 39, 39, 22, 30, 10, 9, 5, 7, 9, 10, 11, 29, 7, 38, 19, 3, 30, 3, 30, 13, 9, 13, 16, 22, 30, 5, 3, 40, 28, 37, 35, 24, 39, 33, 27, 9, 28, 21, 26, 2, 41, 3, 29, 31, 33, 27, 22, 22, 30, 12, 30, 34, 0, 33, 19, 3, 22, 9, 20, 25, 6, 8, 19, 26, 29, 27, 22, 9, 39, 15, 19, 3, 37, 34, 19, 9, 32, 19, 26, 40, 26, 32, 17, 19, 9, 2, 4, 15, 15, 3, 25, 18, 26, 12, 6, 40, 17, 14, 19, 26, 25, 2, 11, 43, 42, 33, 33, 19, 26, 37, 26, 23, 35]
#
# **Convergence time**: 27.4s
#
# **Performance**: 967.113
#
# **Recovery**: 0.970211
#
# **Grade**: 0.999574

# %% [markdown]
# **Graph**:
#
# Check the `circuit_diagrams/challenge_1.pdf` for clear circuit verision.

# %%
# !python3 ../post_process/visualize.py "[40, 30, 18, 1, 30, 31, 36, 22, 9, 23, 15, 19, 26, 42, 39, 39, 22, 30, 10, 9, 5, 7, 9, 10, 11, 29, 7, 38, 19, 3, 30, 3, 30, 13, 9, 13, 16, 22, 30, 5, 3, 40, 28, 37, 35, 24, 39, 33, 27, 9, 28, 21, 26, 2, 41, 3, 29, 31, 33, 27, 22, 22, 30, 12, 30, 34, 0, 33, 19, 3, 22, 9, 20, 25, 6, 8, 19, 26, 29, 27, 22, 9, 39, 15, 19, 3, 37, 34, 19, 9, 32, 19, 26, 40, 26, 32, 17, 19, 9, 2, 4, 15, 15, 3, 25, 18, 26, 12, 6, 40, 17, 14, 19, 26, 25, 2, 11, 43, 42, 33, 33, 19, 26, 37, 26, 23, 35]" 967.113 0.970211 0.999574

# %% [markdown]
# ![challenge_1.png](attachment:challenge_1.png)

# %% [markdown]
# **Performance**:

# %%
import matplotlib.pyplot as plt

# Data from the table
iterations = [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]
time = [0, 2.1, 4.5, 7.0, 9.4, 11.9, 14.4, 17.1, 19.9, 22.3, 24.9, 27.4, 30.1]
fitness = [146.111, 859.149, 934.359, 946.598, 953.758, 959.416, 964.197, 964.802, 964.324, 965.367, 965.371, 967.113, 967.113]

# Plotting
fig, ax1 = plt.subplots()

ax1.set_xlabel('Iterations')
ax1.set_ylabel('Time (s)', color='tab:blue')
ax1.plot(iterations, time, 'o-', color='tab:blue', label='Time')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('Fitness', color='tab:red')
ax2.plot(iterations, fitness, 's-', color='tab:red', label='Fitness')
ax2.tick_params(axis='y', labelcolor='tab:red')

fig.tight_layout()
plt.title('Performance of Genetic Algorithm for 42 Units')
plt.show()

# %% [markdown]
# ### Conclusion
# The genetic algorithm effectively optimizes the circuit configuration for 42 units, with substantial improvements in fitness values within the first few hundred iterations and stabilization around a high fitness value thereafter. The steady increase in computational time is expected and manageable given the gains in solution quality.
#
# For practical applications, running the algorithm for around 800-1000 iterations seems optimal, balancing computational cost and solution quality.

# %% [markdown]
# ## Challenge 2
#
# **With economic conditions of £100 per kg paid for gerardium and a £300 per kg penalty for waste, and the base physical parameters, what is the optimal circuit for 33 units?**

# %% [markdown]
# **Answer vector**:
#
# [19, 10, 13, 25, 5, 19, 27, 33, 28, 28, 5, 12, 21, 17, 0, 20, 15, 14, 17, 5, 12, 3, 13, 3, 22, 13, 27, 11, 5, 19, 26, 28, 14, 5, 12, 9, 29, 14, 17, 19, 15, 5, 12, 28, 15, 10, 2, 14, 14, 13, 1, 8, 15, 10, 13, 17, 32, 4, 10, 13, 32, 17, 24, 23, 5, 12, 1, 13, 21, 16, 17, 6, 7, 5, 12, 6, 10, 13, 24, 5, 19, 18, 5, 19, 9, 33, 15, 15, 12, 18, 30, 12, 4, 31, 19, 20, 34, 10, 13, 0]
#
# **Convergence time**: 17.3s
#
# **Performance**: 921.623
#
# **Recovery**: 0.930464
#
# **Grade**: 0.998735

# %% [markdown]
# **Graph**:
#
# Check the `circuit_diagrams/challenge_2.pdf` for clear circuit verision.

# %%
# !python3 ../post_process/visualize.py "[19, 10, 13, 25, 5, 19, 27, 33, 28, 28, 5, 12, 21, 17, 0, 20, 15, 14, 17, 5, 12, 3, 13, 3, 22, 13, 27, 11, 5, 19, 26, 28, 14, 5, 12, 9, 29, 14, 17, 19, 15, 5, 12, 28, 15, 10, 2, 14, 14, 13, 1, 8, 15, 10, 13, 17, 32, 4, 10, 13, 32, 17, 24, 23, 5, 12, 1, 13, 21, 16, 17, 6, 7, 5, 12, 6, 10, 13, 24, 5, 19, 18, 5, 19, 9, 33, 15, 15, 12, 18, 30, 12, 4, 31, 19, 20, 34, 10, 13, 0]" 921.623 0.930464 0.998735

# %% [markdown]
# ![challenge_2.png](../circuit_diagrams/challenge_2.png)

# %% [markdown]
# **Performance**:

# %%
import matplotlib.pyplot as plt

# Data from the table for 33 units
iterations = [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
time = [0, 2.3, 5.2, 8.2, 11.3, 14.3, 17.3, 20.5, 23.5, 26.5, 29.6]
fitness = [155.813, 865.109, 912.669, 921.196, 921.162, 921.623, 921.623, 921.623, 921.623, 921.623, 921.623]

# Plotting
fig, ax1 = plt.subplots()

ax1.set_xlabel('Iterations')
ax1.set_ylabel('Time (s)', color='tab:blue')
ax1.plot(iterations, time, 'o-', color='tab:blue', label='Time')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('Fitness', color='tab:red')
ax2.plot(iterations, fitness, 's-', color='tab:red', label='Fitness')
ax2.tick_params(axis='y', labelcolor='tab:red')

fig.tight_layout()
plt.title('Performance of Genetic Algorithm for 33 Units')
plt.show()

# %% [markdown]
# ### Conclusion
#
# The fitness values show significant improvement over the iterations, indicating the genetic algorithm's effectiveness in optimizing the circuit configuration. There is a steep increase in fitness values within the first 200 iterations, reaching 912.669 at iteration 200. The fitness values plateau around 921.623 after 500 iterations, indicating that the algorithm has found a near-optimal solution and further iterations provide diminishing returns.
#
# For practical applications, running the algorithm for around 500-600 iterations seems optimal, balancing computational cost and solution quality.

# %% [markdown]
# ## Challenge 3
#
# **With economic conditions of £100 per kg paid for gerardium and a £300 per kg penalty and rate constants as in the table below, what is the optimal circuit for 21 units?**

# %% [markdown]
# **Answer vector**:
#
# [12, 9, 13, 6, 4, 11, 22, 3, 9, 14, 7, 5, 9, 3, 3, 2, 8, 8, 3, 9, 13, 18, 20, 8, 5, 21, 20, 7, 5, 5, 13, 12, 14, 19, 3, 13, 0, 3, 3, 4, 5, 3, 12, 3, 9, 15, 3, 9, 11, 13, 4, 10, 13, 12, 16, 9, 12, 17, 12, 15, 1, 21, 8, 8]
#
# **Convergence time**: 15.6s
#
# **Performance**: 950.073
#
# **Recovery**: 0.958259
#
# **Grade**: 0.998862

# %% [markdown]
# **Graph**:
#
# Check the `circuit_diagrams/challenge_3.pdf` for clear circuit verision.

# %%
# !python3 ../post_process/visualize.py "[12, 9, 13, 6, 4, 11, 22, 3, 9, 14, 7, 5, 9, 3, 3, 2, 8, 8, 3, 9, 13, 18, 20, 8, 5, 21, 20, 7, 5, 5, 13, 12, 14, 19, 3, 13, 0, 3, 3, 4, 5, 3, 12, 3, 9, 15, 3, 9, 11, 13, 4, 10, 13, 12, 16, 9, 12, 17, 12, 15, 1, 21, 8, 8]" 950.073 0.958259 0.998862

# %% [markdown]
# ![challenge_3.png](../circuit_diagrams/challenge_3.png)

# %% [markdown]
# **Performance**:

# %%
import matplotlib.pyplot as plt

# Data from the table for 21 units
iterations = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
time = [0, 5.7, 9.2, 13.1, 17.6, 23.0, 27.3, 32.0, 35.6, 39.0, 42.6]
fitness = [154.083, 825.582, 924.152, 944.428, 950.073, 950.073, 950.073, 950.073, 950.073, 950.073, 950.073]

# Plotting
fig, ax1 = plt.subplots()

ax1.set_xlabel('Iterations')
ax1.set_ylabel('Time (s)', color='tab:blue')
ax1.plot(iterations, time, 'o-', color='tab:blue', label='Time')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('Fitness', color='tab:red')
ax2.plot(iterations, fitness, 's-', color='tab:red', label='Fitness')
ax2.tick_params(axis='y', labelcolor='tab:red')

fig.tight_layout()
plt.title('Performance of Genetic Algorithm for 21 Units')
plt.show()

# %% [markdown]
# ### Conclusion
#
# The genetic algorithm effectively optimizes the circuit configuration for 21 units. The algorithm demonstrates effective convergence, achieving high fitness values in a reasonable computational time. For practical applications, running the algorithm for around 250 iterations seems optimal, balancing computational cost and solution quality.
#
# For practical applications, running the algorithm for around 100-300 iterations seems optimal, balancing computational cost and solution quality.
